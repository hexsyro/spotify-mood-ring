# %% [markdown]
# ## 📓 Notebook 02: Clean & Merge
#
# **Skills practiced:** Pandas DataFrame basics, text normalization,
# `pd.merge()`, measuring and diagnosing merge/match rates.
#
# **Goal:** Combine all scraped year files into one DataFrame, normalize
# title/artist text (via `normalize_text()` in `src/clean.py`), merge with the
# Kaggle audio-features dataset, and report the match percentage — including
# why specific songs failed to match.

# %%
import pandas as pd
import glob

file_list=glob.glob("../data/raw/*.json")
df_list=[pd.read_json(file) for file in file_list]
df=pd.concat(df_list, ignore_index=True)

df.info()
df.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1900 entries, 0 to 1899
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    1900 non-null   int64
#  1   rank    1900 non-null   int64
#  2   title   1900 non-null   str
#  3   artist  1900 non-null   str
# dtypes: int64(2), str(2)
# memory usage: 120.0 KB
#               year         rank
# count  1900.000000  1900.000000
# mean   2012.473684    50.500000
# std       7.730100    28.873669
# min    2001.000000     1.000000
# 25%    2005.000000    25.750000
# 50%    2011.000000    50.500000
# 75%    2020.000000    75.250000
# max    2025.000000   100.000000

# %%
df2=pd.read_csv("../data/raw/spotify_audio_features.csv")

df2.info()
df2.describe()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 114000 entries, 0 to 113999
# Data columns (total 20 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   track_id          114000 non-null  str
#  1   artist            113999 non-null  str
#  2   album_name        113999 non-null  str
#  3   title             113999 non-null  str
#  4   popularity        114000 non-null  int64
#  5   duration_ms       114000 non-null  int64
#  6   explicit          114000 non-null  bool
#  7   danceability      114000 non-null  float64
#  8   energy            114000 non-null  float64
#  9   key               114000 non-null  int64
#  10  loudness          114000 non-null  float64
#  11  mode              114000 non-null  int64
#  12  speechiness       114000 non-null  float64
#  13  acousticness      114000 non-null  float64
#  14  instrumentalness  114000 non-null  float64
#  15  liveness          114000 non-null  float64
# ...
